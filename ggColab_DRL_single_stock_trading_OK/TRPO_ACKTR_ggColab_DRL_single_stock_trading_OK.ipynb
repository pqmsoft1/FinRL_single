# %% [markdown]
# ## DRL_single_stock_trading

# %% [markdown]
# ## Clone code from ggColab_DRL_single_stock_trading_OK.ipynb

# %%
# !pip uninstall -y tensorflow==2.6.0
# !pip install yfinance
# !pip install pandas
# !pip install matplotlib
# !pip install stockstats
# !pip install gym
# !pip install stable-baselines[mpi]
# !pip install tensorflow==1.15.4

# %%
'''
import pkg_resources
import pip
installedPackages = {pkg.key for pkg in pkg_resources.working_set}
required = {'yfinance', 'pandas', 'matplotlib', 'stockstats','stable-baselines','gym','tensorflow'}
missing = required - installedPackages
if missing:
    # !pip install yfinance
    # !pip install pandas
    # !pip install matplotlib
    # !pip install stockstats
    # !pip install gym
    # !pip install stable-baselines[mpi]
    # !pip install tensorflow==1.15.4
'''

# %%
'''
# !pip install yfinance
# !pip install pandas
# !pip install matplotlib
# !pip install stockstats
# !pip install gym
# !pip install stable-baselines[mpi]
# !pip install tensorflow==1.15.4
'''

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.4'

# %%
# !git clone https://github.com/pqmsoft1/FinRL_single.git
# Out:
# Cloning into 'FinRL_single'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 117 (delta 33), reused 92 (delta 13), pack-reused 0
# Receiving objects: 100% (117/117), 8.05 MiB | 16.99 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
# !cd FinRL_single/

# %%
# !ls
# Out:
# FinRL_single  sample_data

# %%
import yfinance as yf
from stockstats import StockDataFrame as Sdf

import pandas as pd
import matplotlib.pyplot as plt

import gym
from stable_baselines import PPO2, DDPG, A2C, ACKTR, TD3, TRPO 
from stable_baselines import DDPG
from stable_baselines import A2C
from stable_baselines import SAC
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines.common.policies import MlpPolicy



#Diable the warnings
import warnings
warnings.filterwarnings('ignore')


#stockerID = "AMZN"
#stockerID = "MSFT"
#stockerID = "TSLA"
#stockerID ="FDX"
#stockerID ="ABMD"
#stockerID ="ABT"
#stockerID = "AAP"
#stockerID = "ABBV"
#stockerID = "AAPL"

'''
#ABBV OK
# TD3
stockerID = "ABBV"
START_DATE_DATA = "2009-01-01"
END_DATE_TRAIN_DATA = "2020-01-01"
END_DATE_DATA = "2021-01-01"

'''


'''
#OK
# TD3
stockerID = "AAPL"
START_DATE_DATA = "2009-01-01"
END_DATE_TRAIN_DATA = "2020-09-01"
END_DATE_DATA = "2021-09-01"
'''



'''

START_DATE_DATA = "2010-01-01"
END_DATE_TRAIN_DATA = "2020-01-01"
END_DATE_DATA = "2021-09-01"
'''

'''
#OK
# TD3
stockerID = "MSFT"
START_DATE_DATA = "2015-01-01"
END_DATE_TRAIN_DATA = "2020-01-01"
END_DATE_DATA = "2021-09-01"
'''

'''
#OK
# TD3
stockerID = "MSFT"
START_DATE_DATA = "2010-01-01"
END_DATE_TRAIN_DATA = "2021-01-01"
END_DATE_DATA = "2021-09-20"

'''

'''
#OK
# TD3
stockerID = "ABBV"
START_DATE_DATA = "2010-01-01"
END_DATE_TRAIN_DATA = "2021-01-01"
END_DATE_DATA = "2021-09-20"

'''


stockerID = "ABBV"
START_DATE_DATA = "2010-01-01"
END_DATE_TRAIN_DATA = "2021-01-01"

END_DATE_DATA = "2021-09-20"

#======================================================== A2C/PPO ==============================================
'''
# A2C/PPO
stockerID = "AMZN"
START_DATE_DATA = "2009-01-01"
END_DATE_TRAIN_DATA = "2021-01-01"
END_DATE_DATA = "2021-09-20"
'''


PATH_CSV_STOCK = stockerID + ".csv"

data_df = yf.download(stockerID, start=START_DATE_DATA, end=END_DATE_DATA)
# reset the index, we want to use numbers instead of dates
data_df=data_df.reset_index()
# convert the column names to standardized names
data_df.columns = ['datadate','open','high','low','close','adjcp','volume']
# save the data to a csv file in your current folder
#data_df.to_csv('AAPL_2009_2020.csv')
#data_df.to_csv('FB_2009_2021.csv')
data_df.to_csv(PATH_CSV_STOCK)
# check missing data 
data_df.isnull().values.any()
# calculate technical indicators like MACD
stock = Sdf.retype(data_df.copy())
# we need to use adjusted close price instead of close price
stock['close'] = stock['adjcp']
data_df['macd'] = stock['macd']
# check missing data again
data_df.isnull().values.any()
# Note that I always use a copy of the original data to try it track step by step.
data_clean = data_df.copy()


import numpy as np
import pandas as pd
from gym.utils import seeding
import gym
from gym import spaces
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Global variables
HMAX_NORMALIZE = 200
INITIAL_ACCOUNT_BALANCE=100000
#INITIAL_ACCOUNT_BALANCE=10000
STOCK_DIM = 1

# transaction fee: 1/1000 reasonable percentage
TRANSACTION_FEE_PERCENT = 0.001
# REWARD_SCALING = 1e-3


class SingleStockEnv(gym.Env):
    """A stock trading environment for OpenAI gym"""
    metadata = {'render.modes': ['human']}

    def __init__(self, df,day = 0):
        #super(StockEnv, self).__init__()
        # date increment
        self.day = day
        self.df = df
        # action_space normalization and the shape is STOCK_DIM
        self.action_space = spaces.Box(low = -1, high = 1,shape = (STOCK_DIM,)) 
        # Shape = 4: [Current Balance]+[prices]+[owned shares] +[macd] 
        self.observation_space = spaces.Box(low=0, high=np.inf, shape = (4,))
        # load data from a pandas dataframe
        self.data = self.df.loc[self.day,:]
        # termination
        self.terminal = False  
        # save the total number of trades
        self.trades = 0
        # initalize state
        self.state = [INITIAL_ACCOUNT_BALANCE] + \
                      [self.data.adjcp] + \
                      [0]*STOCK_DIM + \
                      [self.data.macd] 
        # initialize reward and cost
        self.reward = 0
        self.cost = 0
        
        # memorize the total value, total rewards
        self.asset_memory = [INITIAL_ACCOUNT_BALANCE]
        self.rewards_memory = []

    def _sell_stock(self, index, action):
        # perform sell action based on the sign of the action
        if self.state[index+STOCK_DIM+1] > 0:
            # update balance
            self.state[0] += \
            self.state[index+1]*min(abs(action),self.state[index+STOCK_DIM+1]) * \
             (1- TRANSACTION_FEE_PERCENT)
            # update held shares
            self.state[index+STOCK_DIM+1] -= min(abs(action), self.state[index+STOCK_DIM+1])
            # update transaction costs
            self.cost +=self.state[index+1]*min(abs(action),self.state[index+STOCK_DIM+1]) * \
             TRANSACTION_FEE_PERCENT
            self.trades+=1
        else:
            pass
            
    def _buy_stock(self, index, action):
        # perform buy action based on the sign of the action
        available_amount = self.state[0] // self.state[index+1]
        #update balance
        self.state[0] -= self.state[index+1]*min(available_amount, action)* \
                          (1+ TRANSACTION_FEE_PERCENT)
        # update held shares
        self.state[index+STOCK_DIM+1] += min(available_amount, action)
        # update transaction costs
        self.cost+=self.state[index+1]*min(available_amount, action)* \
                          TRANSACTION_FEE_PERCENT
        self.trades+=1
        
    def step(self, actions):
        self.terminal = self.day >= len(self.df.index.unique())-1
        #print(self.day)
        #print(self.df.index.unique())
        #print(len(self.df.index.unique())-1)
        if self.terminal:
            
            plt.plot(self.asset_memory,'r')
            plt.savefig('account_value.png')
            plt.close()
            
            end_total_asset = self.state[0]+ \
            sum(np.array(self.state[1:(STOCK_DIM+1)])*np.array(self.state[(STOCK_DIM+1):(STOCK_DIM*2+1)]))
            print("previous_total_asset:{}".format(self.asset_memory[0])) 
            print("end_total_asset:{}".format(end_total_asset))
            
            df_total_value = pd.DataFrame(self.asset_memory)
            df_total_value.to_csv('account_value.csv')
            print("total_reward:{}".format(self.state[0]+sum(np.array(self.state[1:(STOCK_DIM+1)])*np.array(self.state[(STOCK_DIM+1):(STOCK_DIM*2+1)]))- INITIAL_ACCOUNT_BALANCE ))
            print("total_cost: ", self.cost)
            print("total trades: ", self.trades)
            
            df_total_value.columns = ['account_value']
            df_total_value['daily_return']=df_total_value.pct_change(1)
            
            if df_total_value['daily_return'].std()!=0:
                sharpe = (252**0.5)*df_total_value['daily_return'].mean()/ \
                      df_total_value['daily_return'].std()
                print("Sharpe: ",sharpe)
            df_rewards = pd.DataFrame(self.rewards_memory)
            df_rewards.to_csv('account_rewards.csv')
            return self.state, self.reward, self.terminal,{}

        else:

            # actions are the shares we need to buy, hold, or sell
            actions = actions * HMAX_NORMALIZE
            # calculate begining total asset
            begin_total_asset = self.state[0]+ \
            sum(np.array(self.state[1:(STOCK_DIM+1)])*np.array(self.state[(STOCK_DIM+1):(STOCK_DIM*2+1)]))
            
            # perform buy or sell action
            argsort_actions = np.argsort(actions)
            sell_index = argsort_actions[:np.where(actions < 0)[0].shape[0]]
            buy_index = argsort_actions[::-1][:np.where(actions > 0)[0].shape[0]]

            for index in sell_index:
                # print('take sell action'.format(actions[index]))
                self._sell_stock(index, actions[index])

            for index in buy_index:
                # print('take buy action: {}'.format(actions[index]))
                self._buy_stock(index, actions[index])
            
            # update data, walk a step s'
            self.day += 1
            self.data = self.df.loc[self.day,:]         
            #load next state
            self.state =  [self.state[0]] + \
                          [self.data.adjcp] + \
                          list(self.state[(STOCK_DIM+1):(STOCK_DIM*2+1)]) +\
                          [self.data.macd]
                        
            # calculate the end total asset
            end_total_asset = self.state[0]+ \
            sum(np.array(self.state[1:(STOCK_DIM+1)])*np.array(self.state[(STOCK_DIM+1):(STOCK_DIM*2+1)]))
            self.reward = end_total_asset - begin_total_asset  
            self.rewards_memory.append(self.reward)
            #self.reward = self.reward * REWARD_SCALING
            self.asset_memory.append(end_total_asset)

        return self.state, self.reward, self.terminal, {}

    def reset(self):
        self.asset_memory = [INITIAL_ACCOUNT_BALANCE]
        self.day = 0
        self.data = self.df.loc[self.day,:]
        self.cost = 0
        self.trades = 0
        self.terminal = False 
        self.rewards_memory = []
        #initiate state
        self.state = [INITIAL_ACCOUNT_BALANCE] + \
                      [self.data.adjcp] + \
                      [0]*STOCK_DIM + \
                      [self.data.macd]
        return self.state
    
    def render(self, mode='human'):
        return self.state

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]


train = data_clean[(data_clean.datadate>=START_DATE_DATA) & (data_clean.datadate < END_DATE_TRAIN_DATA)]
# the index needs to start from 0
train=train.reset_index(drop=True)

## Model Training: 4 models, PPO A2C, DDPG, TD3


'''
#===================================== ppo =====================================

## Model 1: PPO

#tensorboard --logdir ./single_stock_tensorboard/
env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_ppo = PPO2('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
model_ppo.learn(total_timesteps=100000,tb_log_name="run_aapl_ppo")
#model_ppo.save('AAPL_ppo_100k')
#model_ppo.save('AAPL_ppo_100k')
#model_sticker_save = 'FB_ppo_100k'
model_sticker_save = model_sticker_save = stockerID + '_PPO_100k'
model_ppo.save(model_sticker_save)



env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_ppo = PPO2('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
#model_ppo.load('AAPL_ppo_100k.zip')
model_ppo.load(model_sticker_save)
model = model_ppo

#===================================== ppo =====================================
'''
'''
#===================================== A2C =====================================

## Model 1: A2C

#tensorboard --logdir ./single_stock_tensorboard/
env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_a2c = A2C('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
#model_a2c.learn(total_timesteps=100000,tb_log_name="run_aapl_a2c")
model_a2c.learn(total_timesteps=2000000,tb_log_name="run_aapl_a2c")

model_sticker_save = model_sticker_save = stockerID + '_PPO_100k'
model_a2c.save(model_sticker_save)


env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_a2c = A2C('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
model_a2c.load(model_sticker_save)

model = model_a2c


#===================================== A2C =====================================
'''

'''

#==================================== A3C ======================================


model_sticker_save = stockerID + '_A3C_100k'


#tensorboard --logdir ./single_stock_tensorboard/
#DQN<DDPG<TD3
env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_A3C = A3C('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")

model_A3C.learn(total_timesteps=200000,tb_log_name="run_aapl_A3C")

model_A3C.save(model_sticker_save)


env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_A3C = A3C('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
#model_td3.load('AAPL_td3_50k.zip')

model_A3C.load(model_sticker_save)
model = model_A3C


#==================================== A3C ======================================
'''

'''
#===================================== TD3 =====================================

model_sticker_save = stockerID + '_TD3_100k'


#tensorboard --logdir ./single_stock_tensorboard/
#DQN<DDPG<TD3
env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_td3 = TD3('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
#model_td3.learn(total_timesteps=100000,tb_log_name="run_aapl_td3")
#model_td3.save('AAPL_td3_50k')
#model_td3.learn(total_timesteps=100000,tb_log_name="run_aapl_td3")
model_td3.learn(total_timesteps=200000,tb_log_name="run_aapl_td3")



#model_td3.save('AAPL_td3_50k')
model_td3.save(model_sticker_save)


env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_td3 = TD3('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
#model_td3.load('AAPL_td3_50k.zip')

model_td3.load(model_sticker_save)
model = model_td3

#===================================== TD3 =====================================
'''


'''
#==================================== SAC ======================================



model_sticker_save = stockerID + '_SAC_100k'


#tensorboard --logdir ./single_stock_tensorboard/
#DQN<DDPG<TD3
env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_sac = SAC('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
#model_td3.learn(total_timesteps=100000,tb_log_name="run_aapl_td3")
#model_td3.save('AAPL_td3_50k')
#model_td3.learn(total_timesteps=100000,tb_log_name="run_aapl_td3")
model_sac.learn(total_timesteps=100000,tb_log_name="run_aapl_td3")



#model_td3.save('AAPL_td3_50k')
model_sac.save(model_sticker_save)


env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_sac = SAC('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
#model_td3.load('AAPL_td3_50k.zip')

model_sac.load(model_sticker_save)
model = model_sac


#==================================== SAC ======================================


'''
'''
#==================================== ACKTR ======================================



model_sticker_save = stockerID + '_ACKTR_100k'


#tensorboard --logdir ./single_stock_tensorboard/
#DQN<DDPG<TD3
env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_ACKTR = ACKTR('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
#model_td3.learn(total_timesteps=100000,tb_log_name="run_aapl_td3")
#model_td3.save('AAPL_td3_50k')
#model_td3.learn(total_timesteps=100000,tb_log_name="run_aapl_td3")
model_ACKTR.learn(total_timesteps=100000,tb_log_name="run_aapl_ACKTR")



#model_td3.save('AAPL_td3_50k')
model_ACKTR.save(model_sticker_save)


env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_ACKTR = ACKTR('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
#model_td3.load('AAPL_td3_50k.zip')

model_ACKTR.load(model_sticker_save)
model = model_ACKTR


#==================================== ACKTR ======================================
'''





'''
#===================================== DDPG =====================================
model_sticker_save = stockerID + '_DDPG_100k'


#tensorboard --logdir ./single_stock_tensorboard/
env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_ddpg = DDPG('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
model_ddpg.learn(total_timesteps=100000, tb_log_name="run_aapl_ddpg")

model_ddpg.save(model_sticker_save)


env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_ddpg = DDPG('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
model_ddpg.load(model_sticker_save)

model = model_ddpg

#===================================== DDPG =====================================
'''


#==================================== TRPO ======================================



model_sticker_save = stockerID + '_TRPO_100k'


#tensorboard --logdir ./single_stock_tensorboard/
#DQN<DDPG<TD3
env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_TRPO = TRPO('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")

model_TRPO.learn(total_timesteps=200000,tb_log_name="run_aapl_TRPO")



#model_td3.save('AAPL_td3_50k')
model_TRPO.save(model_sticker_save)


env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_TRPO = TRPO('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
#model_td3.load('AAPL_td3_50k.zip')

model_TRPO.load(model_sticker_save)
model = model_TRPO


#==================================== TRPO ======================================
# Out:
# [*********************100%***********************]  1 of 1 completed
# previous_total_asset:100000
# end_total_asset:204935.89398825009
# total_reward:104935.89398825009
# total_cost:  13417.703176796353
# total trades:  2003
# Sharpe:  0.5458155764416825
# previous_total_asset:100000
# end_total_asset:219292.68643612205
# total_reward:119292.68643612205
# total_cost:  14084.234761937727
# total trades:  2011
# Sharpe:  0.5655278380594638
# previous_total_asset:100000
# end_total_asset:178875.0445177062
# total_reward:78875.0445177062
# total_cost:  14235.482652869185
# total trades:  2011
# Sharpe:  0.46056666926809775
# previous_total_asset:100000
# end_total_asset:308458.34587780613
# total_reward:208458.34587780613
# total_cost:  14419.741424349233
# total trades:  2005
# Sharpe:  0.7078095063570349
# previous_total_asset:100000
# end_total_asset:207703.83987290686
# total_reward:107703.83987290686
# total_cost:  14593.7937159144
# total trades:  2001
# Sharpe:  0.6096926614938598
# previous_total_asset:100000
# end_total_asset:262102.03985940758
# total_reward:162102.03985940758
# total_cost:  14001.049358991211
# total trades:  2000
# Sharpe:  0.7447485261201489
# previous_total_asset:100000
# end_total_asset:258658.97486953283
# total_reward:158658.97486953283
# total_cost:  15086.912853967957
# total trades:  2012
# Sharpe:  0.6824615546422081
# previous_total_asset:100000
# end_total_asset:185242.28815509577
# total_reward:85242.28815509577
# total_cost:  14742.763876887318
# total trades:  2007
# Sharpe:  0.46923757530522325
# previous_total_asset:100000
# end_total_asset:162003.33743577515
# total_reward:62003.337435775145
# total_cost:  14448.944751643445
# total trades:  1999
# Sharpe:  0.39683078746484474
# previous_total_asset:100000
# end_total_asset:281635.28205155197
# total_reward:181635.28205155197
# total_cost:  14594.674783196746
# total trades:  2012
# Sharpe:  0.7294373721978492
# previous_total_asset:100000
# end_total_asset:318665.8910199769
# total_reward:218665.89101997687
# total_cost:  14767.16254327731
# total trades:  2012
# Sharpe:  0.7886084242851711
# previous_total_asset:100000
# end_total_asset:210320.38514185042
# total_reward:110320.38514185042
# total_cost:  13961.0889012933
# total trades:  1993
# Sharpe:  0.607832294075944
# previous_total_asset:100000
# end_total_asset:246332.72982578556
# total_reward:146332.72982578556
# total_cost:  14374.995798202803
# total trades:  2011
# Sharpe:  0.6005782615762711
# previous_total_asset:100000
# end_total_asset:258491.41256533703
# total_reward:158491.41256533703
# total_cost:  14485.296422058324
# total trades:  2012
# Sharpe:  0.6354479606287795
# previous_total_asset:100000
# end_total_asset:268216.0132938439
# total_reward:168216.0132938439
# total_cost:  14604.074905978381
# total trades:  2009
# Sharpe:  0.6517140320595853
# previous_total_asset:100000
# end_total_asset:265142.69752088777
# total_reward:165142.69752088777
# total_cost:  14655.926815434137
# total trades:  2012
# Sharpe:  0.6319534247875914
# previous_total_asset:100000
# end_total_asset:192392.9839003925
# total_reward:92392.98390039249
# total_cost:  14219.551214341529
# total trades:  2008
# Sharpe:  0.49786862210874133
# previous_total_asset:100000
# end_total_asset:267394.9034009755
# total_reward:167394.9034009755
# total_cost:  14073.168526973232
# total trades:  2004
# Sharpe:  0.6686674500321673
# previous_total_asset:100000
# end_total_asset:196680.64804744034
# total_reward:96680.64804744034
# total_cost:  13956.50700596626
# total trades:  1991
# Sharpe:  0.51843769131947
# previous_total_asset:100000
# end_total_asset:188347.149680364
# total_reward:88347.149680364
# total_cost:  14288.281997722177
# total trades:  2005
# Sharpe:  0.46840447782509775
# previous_total_asset:100000
# end_total_asset:179409.38925578925
# total_reward:79409.38925578925
# total_cost:  13845.975225800727
# total trades:  1995
# Sharpe:  0.4579029648875784
# previous_total_asset:100000
# end_total_asset:307013.3848950103
# total_reward:207013.38489501033
# total_cost:  13868.920805351047
# total trades:  2013
# Sharpe:  0.6920600430087738
# previous_total_asset:100000
# end_total_asset:303764.8786346002
# total_reward:203764.8786346002
# total_cost:  13921.406442878804
# total trades:  2011
# Sharpe:  0.7052559969660642
# previous_total_asset:100000
# end_total_asset:299429.71718095837
# total_reward:199429.71718095837
# total_cost:  13322.48107691334
# total trades:  2014
# Sharpe:  0.6590448571044126
# previous_total_asset:100000
# end_total_asset:275490.6156039749
# total_reward:175490.6156039749
# total_cost:  13352.78790373877
# total trades:  2011
# Sharpe:  0.6267486394341586
# previous_total_asset:100000
# end_total_asset:318220.5780334848
# total_reward:218220.5780334848
# total_cost:  13452.060655002922
# total trades:  2014
# Sharpe:  0.6855452123666734
# previous_total_asset:100000
# end_total_asset:337531.7149137684
# total_reward:237531.7149137684
# total_cost:  13464.042860869782
# total trades:  2014
# Sharpe:  0.7109894835690663
# previous_total_asset:100000
# end_total_asset:337231.3583894084
# total_reward:237231.3583894084
# total_cost:  13033.50506368505
# total trades:  2013
# Sharpe:  0.7128551258145968
# previous_total_asset:100000
# end_total_asset:293978.1504797701
# total_reward:193978.1504797701
# total_cost:  13100.261830079839
# total trades:  2010
# Sharpe:  0.6519539242821836
# previous_total_asset:100000
# end_total_asset:322339.969889599
# total_reward:222339.96988959902
# total_cost:  12950.74639244228
# total trades:  2006
# Sharpe:  0.6971654354389943
# previous_total_asset:100000
# end_total_asset:328987.2627279966
# total_reward:228987.26272799663
# total_cost:  12567.138960841914
# total trades:  2014
# Sharpe:  0.6904932917342945
# previous_total_asset:100000
# end_total_asset:340791.6910438334
# total_reward:240791.6910438334
# total_cost:  12957.131942947706
# total trades:  2014
# Sharpe:  0.7088375061566572
# previous_total_asset:100000
# end_total_asset:362017.3215926853
# total_reward:262017.3215926853
# total_cost:  13057.94899128476
# total trades:  2014
# Sharpe:  0.7343200184984912
# previous_total_asset:100000
# end_total_asset:356782.74213946343
# total_reward:256782.74213946343
# total_cost:  12643.588367690003
# total trades:  2014
# Sharpe:  0.7238229624927714
# previous_total_asset:100000
# end_total_asset:338698.714044901
# total_reward:238698.71404490102
# total_cost:  12753.473486980503
# total trades:  2014
# Sharpe:  0.6984993739271469
# previous_total_asset:100000
# end_total_asset:355150.9683632187
# total_reward:255150.9683632187
# total_cost:  13090.686727562837
# total trades:  2013
# Sharpe:  0.7350398688028336
# previous_total_asset:100000
# end_total_asset:355046.67197272874
# total_reward:255046.67197272874
# total_cost:  11936.002669335083
# total trades:  2014
# Sharpe:  0.7442234383098972
# previous_total_asset:100000
# end_total_asset:280764.89603885496
# total_reward:180764.89603885496
# total_cost:  12257.454328072718
# total trades:  2014
# Sharpe:  0.6599855091747555
# previous_total_asset:100000
# end_total_asset:292182.3663504084
# total_reward:192182.3663504084
# total_cost:  10667.573777677995
# total trades:  2013
# Sharpe:  0.6479499247869863
# previous_total_asset:100000
# end_total_asset:362951.7555448342
# total_reward:262951.7555448342
# total_cost:  11626.626123826503
# total trades:  2014
# Sharpe:  0.7460908436930771
# previous_total_asset:100000
# end_total_asset:268296.31270427676
# total_reward:168296.31270427676
# total_cost:  12388.268125440198
# total trades:  2014
# Sharpe:  0.6149144593752254
# previous_total_asset:100000
# end_total_asset:284933.12422623247
# total_reward:184933.12422623247
# total_cost:  12228.319153739802
# total trades:  2011
# Sharpe:  0.6435628068993807
# previous_total_asset:100000
# end_total_asset:333684.12439016404
# total_reward:233684.12439016404
# total_cost:  12053.52905842866
# total trades:  2014
# Sharpe:  0.7126849590886359
# previous_total_asset:100000
# end_total_asset:295465.1656438392
# total_reward:195465.16564383922
# total_cost:  11624.571190113675
# total trades:  2012
# Sharpe:  0.6533915600582896
# previous_total_asset:100000
# end_total_asset:252172.6774738571
# total_reward:152172.6774738571
# total_cost:  13090.480395759263
# total trades:  2013
# Sharpe:  0.6135315700589774
# previous_total_asset:100000
# end_total_asset:325580.20162765123
# total_reward:225580.20162765123
# total_cost:  13128.834242425593
# total trades:  2012
# Sharpe:  0.7393672145275342
# previous_total_asset:100000
# end_total_asset:315995.6484659571
# total_reward:215995.64846595709
# total_cost:  12325.030886485876
# total trades:  2012
# Sharpe:  0.6911224360464271
# previous_total_asset:100000
# end_total_asset:309702.89150242246
# total_reward:209702.89150242246
# total_cost:  12881.723455015299
# total trades:  2013
# Sharpe:  0.6819828483502971
# previous_total_asset:100000
# end_total_asset:334185.6837750248
# total_reward:234185.68377502478
# total_cost:  13051.710945676161
# total trades:  2014
# Sharpe:  0.706559032976925
# previous_total_asset:100000
# end_total_asset:349741.9987511253
# total_reward:249741.9987511253
# total_cost:  12906.948961744825
# total trades:  2013
# Sharpe:  0.7322926345479325
# previous_total_asset:100000
# end_total_asset:313659.88210325676
# total_reward:213659.88210325676
# total_cost:  13583.782110807037
# total trades:  2014
# Sharpe:  0.7009203690329519
# previous_total_asset:100000
# end_total_asset:281064.912434275
# total_reward:181064.91243427497
# total_cost:  12731.789102264527
# total trades:  2014
# Sharpe:  0.6564593152550905
# previous_total_asset:100000
# end_total_asset:302029.1166081343
# total_reward:202029.1166081343
# total_cost:  11812.962086310272
# total trades:  2009
# Sharpe:  0.6879028375098034
# previous_total_asset:100000
# end_total_asset:278622.3250418668
# total_reward:178622.3250418668
# total_cost:  12557.535465694165
# total trades:  2010
# Sharpe:  0.6752810841701821
# previous_total_asset:100000
# end_total_asset:184717.43875568794
# total_reward:84717.43875568794
# total_cost:  11959.77404431904
# total trades:  2009
# Sharpe:  0.4845278777394395
# previous_total_asset:100000
# end_total_asset:186242.93540555565
# total_reward:86242.93540555565
# total_cost:  11023.555170828131
# total trades:  1929
# Sharpe:  0.6233610974448015
# previous_total_asset:100000
# end_total_asset:241825.91925037352
# total_reward:141825.91925037352
# total_cost:  9722.42783563273
# total trades:  1981
# Sharpe:  0.67373565941208
# previous_total_asset:100000
# end_total_asset:252113.01336394384
# total_reward:152113.01336394384
# total_cost:  7826.989263023265
# total trades:  2006
# Sharpe:  0.6018997232352146
# previous_total_asset:100000
# end_total_asset:175121.19292795868
# total_reward:75121.19292795868
# total_cost:  12229.426050967571
# total trades:  1930
# Sharpe:  0.5979260004679408
# previous_total_asset:100000
# end_total_asset:186658.1364929096
# total_reward:86658.1364929096
# total_cost:  11735.689304460846
# total trades:  1941
# Sharpe:  0.5673206205490359
# previous_total_asset:100000
# end_total_asset:230500.07517448638
# total_reward:130500.07517448638
# total_cost:  10396.36239399995
# total trades:  2001
# Sharpe:  0.5642825206000762
# previous_total_asset:100000
# end_total_asset:369333.96937027713
# total_reward:269333.96937027713
# total_cost:  8963.789681836422
# total trades:  2014
# Sharpe:  0.7698643136062374
# previous_total_asset:100000
# end_total_asset:374930.3860637992
# total_reward:274930.3860637992
# total_cost:  10683.51267642496
# total trades:  2010
# Sharpe:  0.8017040534472142
# previous_total_asset:100000
# end_total_asset:264850.23245097965
# total_reward:164850.23245097965
# total_cost:  12687.302062625657
# total trades:  2001
# Sharpe:  0.6775477962541064
# previous_total_asset:100000
# end_total_asset:294563.1396486587
# total_reward:194563.1396486587
# total_cost:  11174.711528691168
# total trades:  2006
# Sharpe:  0.6883812133577484
# previous_total_asset:100000
# end_total_asset:217095.83905578393
# total_reward:117095.83905578393
# total_cost:  11971.24052597572
# total trades:  1998
# Sharpe:  0.6156116074827697
# previous_total_asset:100000
# end_total_asset:180797.83875796784
# total_reward:80797.83875796784
# total_cost:  11918.77808406665
# total trades:  1992
# Sharpe:  0.4597641429518844
# previous_total_asset:100000
# end_total_asset:242522.75427538936
# total_reward:142522.75427538936
# total_cost:  10797.460459017515
# total trades:  2004
# Sharpe:  0.5890095938653247
# previous_total_asset:100000
# end_total_asset:289553.27939959307
# total_reward:189553.27939959307
# total_cost:  9142.724731827611
# total trades:  2013
# Sharpe:  0.6477789407005402
# previous_total_asset:100000
# end_total_asset:307571.2852986419
# total_reward:207571.2852986419
# total_cost:  7088.145244963531
# total trades:  2010
# Sharpe:  0.6749957392196878
# previous_total_asset:100000
# end_total_asset:324286.95371206134
# total_reward:224286.95371206134
# total_cost:  6213.215701632582
# total trades:  2011
# Sharpe:  0.679438015999429
# previous_total_asset:100000
# end_total_asset:336471.9122380847
# total_reward:236471.9122380847
# total_cost:  6766.358579431782
# total trades:  2014
# Sharpe:  0.6967205009598868
# previous_total_asset:100000
# end_total_asset:240821.79930965303
# total_reward:140821.79930965303
# total_cost:  9483.141553702255
# total trades:  1974
# Sharpe:  0.6715288514831801
# previous_total_asset:100000
# end_total_asset:126524.55911156765
# total_reward:26524.55911156765
# total_cost:  8447.211994232464
# total trades:  1929
# Sharpe:  0.25292926402496174
# previous_total_asset:100000
# end_total_asset:319552.4701711235
# total_reward:219552.4701711235
# total_cost:  6813.041387277423
# total trades:  2014
# Sharpe:  0.6931785625429303
# previous_total_asset:100000
# end_total_asset:109632.57648364492
# total_reward:9632.576483644923
# total_cost:  8210.288780565757
# total trades:  1812
# Sharpe:  0.1761339018920073
# previous_total_asset:100000
# end_total_asset:144012.99445701658
# total_reward:44012.99445701658
# total_cost:  9546.268129396598
# total trades:  1896
# Sharpe:  0.37686183314522137
# previous_total_asset:100000
# end_total_asset:266132.2191947324
# total_reward:166132.21919473237
# total_cost:  7084.15187891077
# total trades:  2002
# Sharpe:  0.6459938269774854
# previous_total_asset:100000
# end_total_asset:337685.02351416054
# total_reward:237685.02351416054
# total_cost:  6967.462402726408
# total trades:  2011
# Sharpe:  0.7123197556734407
# previous_total_asset:100000
# end_total_asset:195633.27377014834
# total_reward:95633.27377014834
# total_cost:  9059.502154906257
# total trades:  2007
# Sharpe:  0.5133639753664433
# previous_total_asset:100000
# end_total_asset:211891.87030499184
# total_reward:111891.87030499184
# total_cost:  9568.490178769935
# total trades:  1958
# Sharpe:  0.6267383407445101
# previous_total_asset:100000
# end_total_asset:282928.04952473746
# total_reward:182928.04952473746
# total_cost:  9145.882214331403
# total trades:  1995
# Sharpe:  0.6710973060218919
# previous_total_asset:100000
# end_total_asset:147037.40358907965
# total_reward:47037.40358907965
# total_cost:  9680.837130526841
# total trades:  1986
# Sharpe:  0.34148239225166066
# previous_total_asset:100000
# end_total_asset:150514.3444856188
# total_reward:50514.344485618814
# total_cost:  9610.527698657024
# total trades:  1875
# Sharpe:  0.44070196220833907
# previous_total_asset:100000
# end_total_asset:165927.00838130162
# total_reward:65927.00838130162
# total_cost:  11093.721852817785
# total trades:  1979
# Sharpe:  0.5428065064501144
# previous_total_asset:100000
# end_total_asset:173026.38931951477
# total_reward:73026.38931951477
# total_cost:  9395.474555236042
# total trades:  1910
# Sharpe:  0.6395634740533239
# previous_total_asset:100000
# end_total_asset:183147.76572771976
# total_reward:83147.76572771976
# total_cost:  9302.037002041525
# total trades:  1905
# Sharpe:  0.6828011286320185
# previous_total_asset:100000
# end_total_asset:150163.56928425637
# total_reward:50163.56928425637
# total_cost:  9014.04453960122
# total trades:  1929
# Sharpe:  0.4397967968420932
# previous_total_asset:100000
# end_total_asset:105301.57180827537
# total_reward:5301.571808275374
# total_cost:  7402.689535879327
# total trades:  1793
# Sharpe:  0.12761392593717863
# previous_total_asset:100000
# end_total_asset:111726.71899197242
# total_reward:11726.718991972419
# total_cost:  8087.885399825196
# total trades:  1865
# Sharpe:  0.20076527400455127
# previous_total_asset:100000
# end_total_asset:105669.93694830847
# total_reward:5669.936948308474
# total_cost:  8315.220051361484
# total trades:  1818
# Sharpe:  0.12505217284670866
# previous_total_asset:100000
# end_total_asset:200343.53986176138
# total_reward:100343.53986176138
# total_cost:  9929.79202834463
# total trades:  1908
# Sharpe:  0.8749724581350652
# previous_total_asset:100000
# end_total_asset:344878.1470297746
# total_reward:244878.1470297746
# total_cost:  2308.1134170243963
# total trades:  2009
# Sharpe:  0.7030896827211046
# previous_total_asset:100000
# end_total_asset:362833.0942920687
# total_reward:262833.0942920687
# total_cost:  4433.156474325107
# total trades:  2013
# Sharpe:  0.7274657537719045
# previous_total_asset:100000
# end_total_asset:308550.6616820695
# total_reward:208550.66168206948
# total_cost:  4758.004968894811
# total trades:  2014
# Sharpe:  0.658562540663468
# previous_total_asset:100000
# end_total_asset:395270.3665062294
# total_reward:295270.3665062294
# total_cost:  3660.264559653886
# total trades:  2014
# Sharpe:  0.7546730252629347
# previous_total_asset:100000
# end_total_asset:396268.042782555
# total_reward:296268.042782555
# total_cost:  3234.4768232004785
# total trades:  2011
# Sharpe:  0.7553202796262006
# previous_total_asset:100000
# end_total_asset:389701.8741264647
# total_reward:289701.8741264647
# total_cost:  3756.1814640376424
# total trades:  2014
# Sharpe:  0.7497771913653697
# previous_total_asset:100000
# end_total_asset:400654.55817676854
# total_reward:300654.55817676854
# total_cost:  3709.4457156216463
# total trades:  2014
# Sharpe:  0.7596492042455294
# previous_total_asset:100000
# end_total_asset:401597.962954281
# total_reward:301597.962954281
# total_cost:  2272.8700594381667
# total trades:  2014
# Sharpe:  0.7607131054088707
# previous_total_asset:100000
# end_total_asset:394538.968646265
# total_reward:294538.968646265
# total_cost:  2835.244317345006
# total trades:  2013
# Sharpe:  0.7513721950629193
# previous_total_asset:100000
# end_total_asset:403888.62762542674
# total_reward:303888.62762542674
# total_cost:  3982.0604653349083
# total trades:  2014
# Sharpe:  0.7620589986124631
# previous_total_asset:100000
# end_total_asset:410501.511701622
# total_reward:310501.511701622
# total_cost:  4277.921314057391
# total trades:  2014
# Sharpe:  0.7692724375373193
# previous_total_asset:100000
# end_total_asset:396423.8674542766
# total_reward:296423.8674542766
# total_cost:  3806.35067553251
# total trades:  2014
# Sharpe:  0.7532034900935084
# previous_total_asset:100000
# end_total_asset:404037.3235677676
# total_reward:304037.3235677676
# total_cost:  4165.6950470658385
# total trades:  2014
# Sharpe:  0.7618129229572554
# previous_total_asset:100000
# end_total_asset:402894.59743063414
# total_reward:302894.59743063414
# total_cost:  4149.403037606501
# total trades:  2014
# Sharpe:  0.7601918034256626
# previous_total_asset:100000
# end_total_asset:402635.8482980219
# total_reward:302635.8482980219
# total_cost:  4006.7579011828398
# total trades:  2013
# Sharpe:  0.7605154902975727
# previous_total_asset:100000
# end_total_asset:404484.34151217865
# total_reward:304484.34151217865
# total_cost:  3348.9913154587553
# total trades:  2014
# Sharpe:  0.7627980093287137
# previous_total_asset:100000
# end_total_asset:391473.0367308369
# total_reward:291473.0367308369
# total_cost:  3021.1756618949
# total trades:  2014
# Sharpe:  0.7480131185837096
# previous_total_asset:100000
# end_total_asset:402839.0518949207
# total_reward:302839.0518949207
# total_cost:  2974.008814259895
# total trades:  2014
# Sharpe:  0.7590060507013308
# previous_total_asset:100000
# end_total_asset:396809.3136757271
# total_reward:296809.3136757271
# total_cost:  4523.525358637509
# total trades:  2014
# Sharpe:  0.7549599189776197
# previous_total_asset:100000
# end_total_asset:384417.8894687454
# total_reward:284417.8894687454
# total_cost:  5174.900518242866
# total trades:  2014
# Sharpe:  0.7425547929171425
# previous_total_asset:100000
# end_total_asset:405288.25900516124
# total_reward:305288.25900516124
# total_cost:  5250.06496570622
# total trades:  2014
# Sharpe:  0.7664014428174861
# previous_total_asset:100000
# end_total_asset:399176.4196845455
# total_reward:299176.4196845455
# total_cost:  5488.335999503647
# total trades:  2014
# Sharpe:  0.7592509129044671
# previous_total_asset:100000
# end_total_asset:386179.90289896727
# total_reward:286179.90289896727
# total_cost:  3302.609704929551
# total trades:  2014
# Sharpe:  0.7449394044351151
# previous_total_asset:100000
# end_total_asset:398742.3238207675
# total_reward:298742.3238207675
# total_cost:  3076.276816365758
# total trades:  2014
# Sharpe:  0.7558115511975688
# previous_total_asset:100000
# end_total_asset:398394.85521869006
# total_reward:298394.85521869006
# total_cost:  3143.7772489072586
# total trades:  2014
# Sharpe:  0.7546218874788917
# previous_total_asset:100000
# end_total_asset:399081.42708960455
# total_reward:299081.42708960455
# total_cost:  4037.230735390985
# total trades:  2014
# Sharpe:  0.7563640793073072
# previous_total_asset:100000
# end_total_asset:390860.87068679294
# total_reward:290860.87068679294
# total_cost:  3994.697350649281
# total trades:  2014
# Sharpe:  0.7479565354678702
# previous_total_asset:100000
# end_total_asset:397240.6395345553
# total_reward:297240.6395345553
# total_cost:  3901.251926139689
# total trades:  2014
# Sharpe:  0.754707272953973
# previous_total_asset:100000
# end_total_asset:405725.140428907
# total_reward:305725.140428907
# total_cost:  4032.661276637572
# total trades:  2013
# Sharpe:  0.7635633512942452
# previous_total_asset:100000
# end_total_asset:404813.6209347986
# total_reward:304813.6209347986
# total_cost:  3671.196426148026
# total trades:  2014
# Sharpe:  0.7616162542675817
# previous_total_asset:100000
# end_total_asset:399049.3706400144
# total_reward:299049.3706400144
# total_cost:  4262.5965240133255
# total trades:  2014
# Sharpe:  0.7569270498290948
# previous_total_asset:100000
# end_total_asset:388357.82505595195
# total_reward:288357.82505595195
# total_cost:  5009.438973819531
# total trades:  2014
# Sharpe:  0.746005993866734
# previous_total_asset:100000
# end_total_asset:399228.30709463276
# total_reward:299228.30709463276
# total_cost:  4697.475470083691
# total trades:  2014
# Sharpe:  0.7571565414485203
# previous_total_asset:100000
# end_total_asset:406752.99611402827
# total_reward:306752.99611402827
# total_cost:  5388.705524005882
# total trades:  2014
# Sharpe:  0.7666634163954247
# previous_total_asset:100000
# end_total_asset:398827.90620280756
# total_reward:298827.90620280756
# total_cost:  5668.274073809355
# total trades:  2014
# Sharpe:  0.758417853640146
# previous_total_asset:100000
# end_total_asset:393454.77781560237
# total_reward:293454.77781560237
# total_cost:  6481.224585253034
# total trades:  2014
# Sharpe:  0.7539421060378909
# previous_total_asset:100000
# end_total_asset:381911.4701507302
# total_reward:281911.4701507302
# total_cost:  5739.508329793151
# total trades:  2013
# Sharpe:  0.7396189666793297
# previous_total_asset:100000
# end_total_asset:396689.49546996615
# total_reward:296689.49546996615
# total_cost:  5341.073361081284
# total trades:  2013
# Sharpe:  0.7564132464172808
# previous_total_asset:100000
# end_total_asset:388326.6207453467
# total_reward:288326.6207453467
# total_cost:  5603.968062190427
# total trades:  2014
# Sharpe:  0.7452171110154625
# previous_total_asset:100000
# end_total_asset:397396.6430935612
# total_reward:297396.6430935612
# total_cost:  6209.770507323874
# total trades:  2014
# Sharpe:  0.7582315856447587
# previous_total_asset:100000
# end_total_asset:383685.7694517072
# total_reward:283685.7694517072
# total_cost:  7330.099354999469
# total trades:  2013
# Sharpe:  0.7455704137012679
# previous_total_asset:100000
# end_total_asset:394666.212157732
# total_reward:294666.212157732
# total_cost:  9059.39586235368
# total trades:  2014
# Sharpe:  0.7662109157664726
# previous_total_asset:100000
# end_total_asset:382773.0943863958
# total_reward:282773.0943863958
# total_cost:  7820.504800392289
# total trades:  2014
# Sharpe:  0.7443205881924874
# previous_total_asset:100000
# end_total_asset:387013.12521690154
# total_reward:287013.12521690154
# total_cost:  8702.977287617146
# total trades:  2014
# Sharpe:  0.7483661054384029
# previous_total_asset:100000
# end_total_asset:396815.111151693
# total_reward:296815.111151693
# total_cost:  8483.33760763903
# total trades:  2014
# Sharpe:  0.7584259726397095
# previous_total_asset:100000
# end_total_asset:390434.6899025079
# total_reward:290434.6899025079
# total_cost:  7507.995765586435
# total trades:  2014
# Sharpe:  0.7478174761530098
# previous_total_asset:100000
# end_total_asset:395453.1634894026
# total_reward:295453.1634894026
# total_cost:  6779.403177190899
# total trades:  2014
# Sharpe:  0.7536967701273448
# previous_total_asset:100000
# end_total_asset:383611.09465697716
# total_reward:283611.09465697716
# total_cost:  7428.691921928589
# total trades:  2013
# Sharpe:  0.7410295008057789
# previous_total_asset:100000
# end_total_asset:393281.6053587127
# total_reward:293281.6053587127
# total_cost:  8527.840552144982
# total trades:  2014
# Sharpe:  0.7526603012817374
# previous_total_asset:100000
# end_total_asset:391138.34623262566
# total_reward:291138.34623262566
# total_cost:  10151.734004548016
# total trades:  2014
# Sharpe:  0.7515384954908271
# previous_total_asset:100000
# end_total_asset:385551.802284801
# total_reward:285551.802284801
# total_cost:  9180.522994148176
# total trades:  2014
# Sharpe:  0.7441173704861321
# previous_total_asset:100000
# end_total_asset:395882.9302017628
# total_reward:295882.9302017628
# total_cost:  8745.529613543757
# total trades:  2014
# Sharpe:  0.7558614720764628
# previous_total_asset:100000
# end_total_asset:374748.39190851094
# total_reward:274748.39190851094
# total_cost:  9725.01706606571
# total trades:  2014
# Sharpe:  0.7310583052521878
# previous_total_asset:100000
# end_total_asset:391918.5555786368
# total_reward:291918.5555786368
# total_cost:  10696.03563880669
# total trades:  2014
# Sharpe:  0.7534052188415638
# previous_total_asset:100000
# end_total_asset:376039.3027145314
# total_reward:276039.3027145314
# total_cost:  11863.81988956687
# total trades:  2012
# Sharpe:  0.7381927106961139
# previous_total_asset:100000
# end_total_asset:380446.40049052396
# total_reward:280446.40049052396
# total_cost:  12307.015117443032
# total trades:  2014
# Sharpe:  0.7410674889916291

# %%
#====================================================PREDICT=================================================
# Trading
# Assume that we have $100,000 initial capital at 2019-01-01. We use the TD3 model to trade AAPL.
## sau khi chay xong: create file account_rewards.csv, account_value.csv, account_value.png 


test = data_clean[(data_clean.datadate >= END_DATE_TRAIN_DATA) ]
# the index needs to start from 0
test=test.reset_index(drop=True)


#model = model_a2c
#model = model_ppo
#model = model_td3



env_test = DummyVecEnv([lambda: SingleStockEnv(test)])
obs_test = env_test.reset()
print("==============Model Prediction===========")
for i in range(len(test.index.unique())):
    action, _states = model.predict(obs_test)
    obs_test, rewards, dones, info = env_test.step(action)
    env_test.render()

#==> Create file account_rewards.csv, account_value.csv, account_value.png sau khi chay xong


'''
Part 5: Backtest Our Strategy
For simplicity purposes, in the article, we just calculate the Sharpe ratio and the annual return manually.
'''


def get_DRL_sharpe():
    df_total_value=pd.read_csv('account_value.csv',index_col=0)
    df_total_value.columns = ['account_value']
    df_total_value['daily_return']=df_total_value.pct_change(1)
    sharpe = (252**0.5)*df_total_value['daily_return'].mean()/ \
    df_total_value['daily_return'].std()
    
    annual_return = ((df_total_value['daily_return'].mean()+1)**252-1)*100
    print("annual return: ", annual_return)
    print("sharpe ratio: ", sharpe)
    return df_total_value


def get_buy_and_hold_sharpe(test):
    test['daily_return']=test['adjcp'].pct_change(1)
    sharpe = (252**0.5)*test['daily_return'].mean()/ \
    test['daily_return'].std()
    annual_return = ((test['daily_return'].mean()+1)**252-1)*100
    print("annual return: ", annual_return)

    print("sharpe ratio: ", sharpe)
    #return sharpe

df_total_value=get_DRL_sharpe()
get_buy_and_hold_sharpe(test)
DRL_cumulative_return = (df_total_value.account_value.pct_change(1)+1).cumprod()-1
buy_and_hold_cumulative_return = (test.adjcp.pct_change(1)+1).cumprod()-1



# %matplotlib inline
fig, ax = plt.subplots(figsize=(12, 8))

plt.plot(test.datadate, DRL_cumulative_return, color='red',label = "DRL")
plt.plot(test.datadate, buy_and_hold_cumulative_return, label = "Buy & Hold")
titleTmp = "Cumulative Return for " + stockerID + " with Transaction Cost" 
plt.title(titleTmp,size= 20)
plt.legend()
plt.rc('legend',fontsize=15)
plt.rc('xtick', labelsize=15)
plt.rc('ytick', labelsize=15)
# Out:
# ==============Model Prediction===========
# previous_total_asset:100000
# end_total_asset:101535.4115211108
# total_reward:1535.4115211108
# total_cost:  1983.7735266387626
# total trades:  167
# Sharpe:  0.2771491710035655
# annual return:  2.6278990649188927
# sharpe ratio:  0.2771491710035682
# annual return:  10.766287942698426
# sharpe ratio:  0.4876153641555982

# %%
# Import yfinance package
import yfinance as yf

# Import matplotlib for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

start_date = END_DATE_TRAIN_DATA
end_date = END_DATE_DATA

# Set the ticker
#ticker = 'AMZN'
ticker = stockerID


# Get the data
data = yf.download(ticker, start_date, end_date)

# Print 5 rows
#data.tail()

# Plot adjusted close price data
data['Adj Close'].plot()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Model Training: 4 models, PPO A2C, DDPG, TD3
# ## Model 1: PPO

# %%
#tensorboard --logdir ./single_stock_tensorboard/
env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_ppo = PPO2('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
model_ppo.learn(total_timesteps=100000,tb_log_name="run_aapl_ppo")
#model_ppo.save('AAPL_ppo_100k')
#model_ppo.save('AAPL_ppo_100k')
#model_sticker_save = 'FB_ppo_100k'
model_sticker_save = 'amzn_ppo_100k'
model_ppo.save(model_sticker_save)

# %% [markdown]
# ## Model 2: DDPG

# %%
#tensorboard --logdir ./single_stock_tensorboard/
env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_ddpg = DDPG('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
model_ddpg.learn(total_timesteps=100000, tb_log_name="run_aapl_ddpg")
#model_ddpg.save('AAPL_ddpg_50k')

# %%
#model_ddpg.learn(total_timesteps=100000, tb_log_name="run_aapl_ddpg")
model_ddpg.save('AAPL_ddpg_50k')

#model_ddpg.save(model_sticker_save)

# %% [markdown]
# ## Model 3: A2C

# %%
#tensorboard --logdir ./single_stock_tensorboard/
env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_a2c = A2C('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
model_a2c.learn(total_timesteps=100000,tb_log_name="run_aapl_a2c")
#model_a2c.save('AAPL_a2c_50k')

# %%
model_a2c.save('AAPL_a2c_50k')
#model_a2c.save(model_sticker_save)

# %% [markdown]
# ## Model 4: TD3

# %%
#tensorboard --logdir ./single_stock_tensorboard/
#DQN<DDPG<TD3
env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_td3 = TD3('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
#model_td3.learn(total_timesteps=100000,tb_log_name="run_aapl_td3")
#model_td3.save('AAPL_td3_50k')
model_td3.learn(total_timesteps=100000,tb_log_name="run_aapl_td3")
model_td3.save('AAPL_td3_50k')
#model_td3.save(model_sticker_save)

# %% [markdown]
# ## Testing data

# %% [markdown]
# ## Load model from file save

# %% [markdown]
# ## Load model PPO

# %%
env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_ppo = PPO2('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
#model_ppo.load('AAPL_ppo_100k.zip')
model_ppo.load(model_sticker_save)

# %% [markdown]
# ## Load models a2c

# %%
env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_a2c = A2C('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
model_a2c.load(model_sticker_save)

# %% [markdown]
# ## Load model ddpg

# %%
env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_ddpg = DDPG('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
#model_ddpg.load('AAPL_ddpg_50k.zip')
model_ddpg.load(model_sticker_save)

# %% [markdown]
# ## Load model td3

# %%
env_train = DummyVecEnv([lambda: SingleStockEnv(train)])
model_td3 = TD3('MlpPolicy', env_train, tensorboard_log="./single_stock_trading_2_tensorboard/")
model_td3.load('AAPL_td3_50k.zip')

# %% [markdown]
# # Trading
# Assume that we have $100,000 initial capital at 2019-01-01. We use the TD3 model to trade AAPL.
#
# ## sau khi chay xong: create file account_rewards.csv, account_value.csv, account_value.png

# %%
test = data_clean[(data_clean.datadate >= END_DATE_TRAIN_DATA) ]
# the index needs to start from 0
test=test.reset_index(drop=True)

# %%
test

# %%
#model = model_a2c
model = model_ppo
#model = model_td3
#model = model_ddpg
env_test = DummyVecEnv([lambda: SingleStockEnv(test)])
obs_test = env_test.reset()
print("==============Model Prediction===========")
for i in range(len(test.index.unique())):
    action, _states = model.predict(obs_test)
    obs_test, rewards, dones, info = env_test.step(action)
    env_test.render()

#==> Create file account_rewards.csv, account_value.csv, account_value.png sau khi chay xong
# Out:
# ==============Model Prediction===========
# previous_total_asset:100000
# end_total_asset:91214.80049134279
# total_reward:-8785.199508657213
# total_cost:  1216.9028415728942
# total trades:  52
# Sharpe:  -3.1096071839715838

# %% [markdown]
# ## Part 5: Backtest Our Strategy
# For simplicity purposes, in the article, we just calculate the Sharpe ratio and the annual return manually.

# %%
def get_DRL_sharpe():
    df_total_value=pd.read_csv('account_value.csv',index_col=0)
    df_total_value.columns = ['account_value']
    df_total_value['daily_return']=df_total_value.pct_change(1)
    sharpe = (252**0.5)*df_total_value['daily_return'].mean()/ \
    df_total_value['daily_return'].std()
    
    annual_return = ((df_total_value['daily_return'].mean()+1)**252-1)*100
    print("annual return: ", annual_return)
    print("sharpe ratio: ", sharpe)
    return df_total_value


def get_buy_and_hold_sharpe(test):
    test['daily_return']=test['adjcp'].pct_change(1)
    sharpe = (252**0.5)*test['daily_return'].mean()/ \
    test['daily_return'].std()
    annual_return = ((test['daily_return'].mean()+1)**252-1)*100
    print("annual return: ", annual_return)

    print("sharpe ratio: ", sharpe)
    #return sharpe

df_total_value=get_DRL_sharpe()
get_buy_and_hold_sharpe(test)
DRL_cumulative_return = (df_total_value.account_value.pct_change(1)+1).cumprod()-1
buy_and_hold_cumulative_return = (test.adjcp.pct_change(1)+1).cumprod()-1
# Out:
# annual return:  -34.2962179054769
# sharpe ratio:  -3.1096071839715633
# annual return:  -50.82201630086771
# sharpe ratio:  -3.7496910745541077

# %%
#DRL_cumulative_return

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(12, 8))

plt.plot(test.datadate, DRL_cumulative_return, color='red',label = "DRL")
plt.plot(test.datadate, buy_and_hold_cumulative_return, label = "Buy & Hold")
plt.title("Cumulative Return for AAPL with Transaction Cost",size= 20)
plt.legend()
plt.rc('legend',fontsize=15)
plt.rc('xtick', labelsize=15)
plt.rc('ytick', labelsize=15)

# %%
from google.colab import files

files.download('AAPL_a2c_50k.zip')
files.download('AAPL_td3_50k.zip')
files.download('AAPL_ppo_100k.zip')
files.download('AAPL_ddpg_50k.zip')
